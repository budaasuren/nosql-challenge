# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments=db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query ={'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)

# Display the first document in the results using pprint
print(f'total number where hygiene score equals to 20 is {establishments.count_documents(query)}. ')

hygiene_results=list(establishments.find(query))
pprint(hygiene_results[0])
# Out:
# total number where hygiene score equals to 20 is 41.
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cd56a7348837803496d213'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
pd.set_option('display.max_columns', None)

# %%
# Convert the result to a Pandas DataFrame
hygiene_df=pd.DataFrame(hygiene_results)

# Display the number of rows in the DataFrame

print(f'number of rows: {hygiene_df.shape[0]}')

# Display the first 10 rows of the DataFrame
hygiene_df.tail(10)
# Out:
# number of rows: 41
#                          _id   FHRSID  ChangesByServerID  \
# 31  63cd56a93488378034973f8e   668674                  0
# 32  63cd56a9348837803497407a  1286585                  0
# 33  63cd56a9348837803497412a   971735                  0
# 34  63cd56a934883780349742d1  1055935                  0
# 35  63cd56a9348837803497445b  1177878                  0
# 36  63cd56a9348837803497454a  1296829                  0
# 37  63cd56a934883780349748be   514573                  0
# 38  63cd56a93488378034974ab7   124507                  0
# 39  63cd56a93488378034974cd5   479001                  0
# 40  63cd56a93488378034974ec5   107710                  0
#
#    LocalAuthorityBusinessID                   BusinessName  \
# 31             14/00082/COM          Samui Thai Restaurant
# 32            20/00532/FOOD        Pakhtoonkhwa Restaurant
# 33             17/00076/COM               New Happy Garden
# 34            18/00198/FOOD                      Mummy Yum
# 35                   347294                      Gospodina
# 36                   347449              Leo's Bar & Grill
# 37                    44243                     Royal Ribs
# 38              53022999151  Great Hallingbury Manor Hotel
# 39             12/00162/COM               The Dog And Duck
# 40              38127001007               Oriental Cottage
#
#                BusinessType  BusinessTypeID             AddressLine1  \
# 31  Restaurant/Cafe/Canteen               1               The Kinema
# 32  Restaurant/Cafe/Canteen               1          76 Green Street
# 33   Takeaway/sandwich shop            7844        23 Stortford Road
# 34   Takeaway/sandwich shop            7844         34 West Ham Lane
# 35        Retailers - other            4613
# 36  Restaurant/Cafe/Canteen               1
# 37   Takeaway/sandwich shop            7844
# 38  Restaurant/Cafe/Canteen               1  Great Hallingbury Manor
# 39        Pub/bar/nightclub            7843          58 Lower Street
# 40   Takeaway/sandwich shop            7844            1 Mercers Row
#
#                  AddressLine2       AddressLine3       AddressLine4  PostCode  \
# 31            Chelmsford Road             Dunmow                      CM6 1HB
# 32                Forest Gate             London                       E7 8JG
# 33                     Dunmow                                         CM6 1DA
# 34                  Stratford             London                      E15 4SA
# 35  345 High Road Leytonstone                           Leytonstone   E11 4JT
# 36             32 Church Lane                           Leytonstone   E11 1HG
# 37              14 Hatch Lane                             Chingford    E4 6LQ
# 38             Tilekiln Green  Great Hallingbury  Bishops Stortford  CM22 7TJ
# 39                   Stansted              Essex                     CM24 8LR
# 40             Saffron Walden              Essex                     CB10 1HD
#
#    Phone RatingValue     RatingKey           RatingDate LocalAuthorityCode  \
# 31                 0  fhrs_0_en-gb  2022-03-24T00:00:00                122
# 32                 0  fhrs_0_en-gb  2022-06-14T00:00:00                525
# 33                 0  fhrs_0_en-gb  2022-03-28T00:00:00                122
# 34                 0  fhrs_0_en-gb  2022-07-12T00:00:00                525
# 35                 0  fhrs_0_en-gb  2022-06-27T00:00:00                531
# 36                 1  fhrs_1_en-gb  2022-06-15T00:00:00                531
# 37                 0  fhrs_0_en-gb  2022-07-01T00:00:00                531
# 38                 1  fhrs_1_en-gb  2021-07-28T00:00:00                122
# 39                 0  fhrs_0_en-gb  2021-11-11T00:00:00                122
# 40                 0  fhrs_0_en-gb  2022-03-31T00:00:00                122
#
#    LocalAuthorityName            LocalAuthorityWebSite  \
# 31         Uttlesford     http://www.uttlesford.gov.uk
# 32             Newham        https://www.newham.gov.uk
# 33         Uttlesford     http://www.uttlesford.gov.uk
# 34             Newham        https://www.newham.gov.uk
# 35     Waltham Forest  http://www.walthamforest.gov.uk
# 36     Waltham Forest  http://www.walthamforest.gov.uk
# 37     Waltham Forest  http://www.walthamforest.gov.uk
# 38         Uttlesford     http://www.uttlesford.gov.uk
# 39         Uttlesford     http://www.uttlesford.gov.uk
# 40         Uttlesford     http://www.uttlesford.gov.uk
#
#                   LocalAuthorityEmailAddress  \
# 31     environmentalhealth@uttlesford.gov.uk
# 32                        food@newham.gov.uk
# 33     environmentalhealth@uttlesford.gov.uk
# 34                        food@newham.gov.uk
# 35  environmentalhealth@walthamforest.gov.uk
# 36  environmentalhealth@walthamforest.gov.uk
# 37  environmentalhealth@walthamforest.gov.uk
# 38     environmentalhealth@uttlesford.gov.uk
# 39     environmentalhealth@uttlesford.gov.uk
# 40     environmentalhealth@uttlesford.gov.uk
#
#                                                scores SchemeType  \
# 31  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 32  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 33  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 34  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 35  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 36  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 37  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 38  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 39  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 40  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
#
#                                               geocode RightToReply  \
# 31   {'longitude': 0.3659018, 'latitude': 51.8686712}
# 32     {'longitude': 0.031959, 'latitude': 51.543994}
# 33     {'longitude': 0.360846, 'latitude': 51.873055}
# 34     {'longitude': 0.004389, 'latitude': 51.538857}
# 35     {'longitude': 0.005407, 'latitude': 51.555782}
# 36     {'longitude': 0.009101, 'latitude': 51.568245}
# 37      {'longitude': 0.006248, 'latitude': 51.61912}
# 38  {'longitude': 0.207771003246307, 'latitude': 5...
# 39     {'longitude': 0.201087, 'latitude': 51.904039}
# 40      {'longitude': 0.240491, 'latitude': 52.02328}
#
#        Distance  NewRatingPending  \
# 31  4651.099995             False
# 32  4651.233130             False
# 33  4651.444488             False
# 34  4652.049760             False
# 35  4652.632190             False
# 36  4652.953922              True
# 37  4654.920996             False
# 38  4656.798774             False
# 39  4658.344880             False
# 40  4661.334349             False
#
#                                                  meta  \
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
# 33  {'dataSource': None, 'extractDate': '0001-01-0...
# 34  {'dataSource': None, 'extractDate': '0001-01-0...
# 35  {'dataSource': None, 'extractDate': '0001-01-0...
# 36  {'dataSource': None, 'extractDate': '0001-01-0...
# 37  {'dataSource': None, 'extractDate': '0001-01-0...
# 38  {'dataSource': None, 'extractDate': '0001-01-0...
# 39  {'dataSource': None, 'extractDate': '0001-01-0...
# 40  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links longitude latitude
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 33  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 34  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 35  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 36  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 37  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 38  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 39  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 40  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={'LocalAuthorityName':{'$regex':'London'}, 'RatingValue': {'$in': ['4', '5']}}

# Use count_documents to display the number of documents in the result
london_results=establishments.count_documents(query)
print(london_results)

# Display the first document in the results using pprint
london_results=list(establishments.find(query))
pprint(london_results[0])

#for result in range(len(london_results)):
#    print(london_results[result]['RatingValue'])
# Out:
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63cd56a7348837803496ec2f'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
london_df=pd.DataFrame(london_results)

# Display the number of rows in the DataFrame
print(f'number of rows: {london_df.shape[0]}')

# Display the first 10 rows of the DataFrame
london_df.tail(10)
# Out:
# number of rows: 33
#                          _id   FHRSID  ChangesByServerID  \
# 23  63cd56a93488378034973d60  1090019                  0
# 24  63cd56a93488378034973d62  1090025                  0
# 25  63cd56a93488378034973d63  1090027                  0
# 26  63cd56a93488378034973d64  1090028                  0
# 27  63cd56a93488378034973d65  1090018                  0
# 28  63cd56a93488378034973d66  1090024                  0
# 29  63cd56a93488378034973d67  1090016                  0
# 30  63cd56a93488378034973d68   293758                  0
# 31  63cd56a93488378034973d69  1090026                  0
# 32  63cd56a93488378034973d6a  1450220                  0
#
#    LocalAuthorityBusinessID          BusinessName             BusinessType  \
# 23             PI/000033475    MV Tornado clipper  Other catering premises
# 24             PI/000033481  MV Hurricane clipper  Other catering premises
# 25             PI/000033483    MV Cyclone clipper  Other catering premises
# 26             PI/000033484    MV Neptune clipper  Other catering premises
# 27             PI/000033473    MV Mercury clipper  Other catering premises
# 28             PI/000033480     MV Galaxy clipper  Other catering premises
# 29             PI/000033470        MV Sun clipper  Other catering premises
# 30             PI/000002546      Mv Storm Clipper  Other catering premises
# 31             PI/000033482     MV Aurora clipper  Other catering premises
# 32             PI/000038259       Canary Wharf 1V  Other catering premises
#
#     BusinessTypeID                                    AddressLine1  \
# 23            7841  Thames Clippers Unit 12 The Riverside Building
# 24            7841  Thames Clippers Unit 12 The Riverside Building
# 25            7841  Thames Clippers Unit 12 The Riverside Building
# 26            7841  Thames Clippers Unit 12 The Riverside Building
# 27            7841          Thames Clippers 3rd flr Clippers House
# 28            7841  Thames Clippers Unit 12 The Riverside Building
# 29            7841          Thames Clippers 3rd flr Clippers House
# 30            7841  Thames Clippers Unit 12 The Riverside Building
# 31            7841  Thames Clippers Unit 12 The Riverside Building
# 32            7841                              Trinity Buoy Wharf
#
#                                   AddressLine2 AddressLine3 AddressLine4  \
# 23  64 Orchard Place Trinity Buoy Wharf London       London
# 24  64 Orchard Place Trinity Buoy Wharf London       London
# 25  64 Orchard Place Trinity Buoy Wharf London       London
# 26  64 Orchard Place Trinity Buoy Wharf London       London
# 27     Orchard Place Trinity Buoy Wharf London       London
# 28  64 Orchard Place Trinity Buoy Wharf London       London
# 29     Orchard Place Trinity Buoy Wharf London       London
# 30  64 Orchard Place Trinity Buoy Wharf London       London
# 31  64 Orchard Place Trinity Buoy Wharf London       London
# 32                            64 Orchard Place       London
#
#    PostCode Phone RatingValue     RatingKey           RatingDate  \
# 23  E14 0JY                 5  fhrs_5_en-gb  2018-05-02T00:00:00
# 24  E14 0JY                 5  fhrs_5_en-gb  2018-12-14T00:00:00
# 25  E14 0JY                 5  fhrs_5_en-gb  2018-12-14T00:00:00
# 26  E14 0JY                 5  fhrs_5_en-gb  2018-05-02T00:00:00
# 27  E14 0JY                 5  fhrs_5_en-gb  2018-12-14T00:00:00
# 28  E14 0JY                 5  fhrs_5_en-gb  2018-05-02T00:00:00
# 29  E14 0JY                 5  fhrs_5_en-gb  2018-12-14T00:00:00
# 30  E14 0JY                 5  fhrs_5_en-gb  2019-01-11T00:00:00
# 31  E14 0JY                 5  fhrs_5_en-gb  2021-12-03T00:00:00
# 32  E14 0JY                 5  fhrs_5_en-gb  2022-02-25T00:00:00
#
#    LocalAuthorityCode          LocalAuthorityName  \
# 23                508  City of London Corporation
# 24                508  City of London Corporation
# 25                508  City of London Corporation
# 26                508  City of London Corporation
# 27                508  City of London Corporation
# 28                508  City of London Corporation
# 29                508  City of London Corporation
# 30                508  City of London Corporation
# 31                508  City of London Corporation
# 32                508  City of London Corporation
#
#                                 LocalAuthorityWebSite  \
# 23  http://www.cityoflondon.gov.uk/Corporation/hom...
# 24  http://www.cityoflondon.gov.uk/Corporation/hom...
# 25  http://www.cityoflondon.gov.uk/Corporation/hom...
# 26  http://www.cityoflondon.gov.uk/Corporation/hom...
# 27  http://www.cityoflondon.gov.uk/Corporation/hom...
# 28  http://www.cityoflondon.gov.uk/Corporation/hom...
# 29  http://www.cityoflondon.gov.uk/Corporation/hom...
# 30  http://www.cityoflondon.gov.uk/Corporation/hom...
# 31  http://www.cityoflondon.gov.uk/Corporation/hom...
# 32  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#               LocalAuthorityEmailAddress  \
# 23  publicprotection@cityoflondon.gov.uk
# 24  publicprotection@cityoflondon.gov.uk
# 25  publicprotection@cityoflondon.gov.uk
# 26  publicprotection@cityoflondon.gov.uk
# 27  publicprotection@cityoflondon.gov.uk
# 28  publicprotection@cityoflondon.gov.uk
# 29  publicprotection@cityoflondon.gov.uk
# 30  publicprotection@cityoflondon.gov.uk
# 31  publicprotection@cityoflondon.gov.uk
# 32  publicprotection@cityoflondon.gov.uk
#
#                                                scores SchemeType  \
# 23  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 24  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 25  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 26  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 27  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 28  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 29  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 30  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 31  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 32  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                               geocode RightToReply  \
# 23     {'longitude': 0.007816, 'latitude': 51.508259}
# 24     {'longitude': 0.007816, 'latitude': 51.508259}
# 25     {'longitude': 0.007816, 'latitude': 51.508259}
# 26     {'longitude': 0.007816, 'latitude': 51.508259}
# 27  {'longitude': 0.0078159999102354, 'latitude': ...
# 28     {'longitude': 0.007816, 'latitude': 51.508259}
# 29  {'longitude': 0.0078159999102354, 'latitude': ...
# 30     {'longitude': 0.007816, 'latitude': 51.508259}
# 31     {'longitude': 0.007816, 'latitude': 51.508259}
# 32     {'longitude': 0.007815, 'latitude': 51.508259}
#
#        Distance  NewRatingPending  \
# 23  4650.805008             False
# 24  4650.805008             False
# 25  4650.805008             False
# 26  4650.805008             False
# 27  4650.805001             False
# 28  4650.805008             False
# 29  4650.805001             False
# 30  4650.805008             False
# 31  4650.805008             False
# 32  4650.805044             False
#
#                                                  meta  \
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links longitude latitude
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
penang=list(establishments.find({"BusinessName": "Penang Flavours"}))
penang_longitude=penang[0]['geocode']['longitude']
penang_latitude=penang[0]['geocode']['latitude']
print(f'{penang_longitude} ,{penang_latitude}' )
# Out:
# 0.08384 ,51.490142

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score


degree_search = 0.01
latitude = penang_latitude 
longitude = penang_longitude

query ={'RatingValue':'5','geocode.latitude':{'$gte':latitude - degree_search, '$lte': latitude + degree_search},\
                        'geocode.longitude':{'$gte':longitude - degree_search, '$lte': longitude + degree_search}
       } 
sort = [('scores.Hygiene',1)]

limit=1


print(f'number of documnets that meets the criteria : {establishments.count_documents(query)}')

# Print the first results
pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# number of documnets that meets the criteria : 87
# [{'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'London',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('63cd56a93488378034972a44'),
#   'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#   'latitude': None,
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}]

# %%
# Convert result to Pandas DataFrame
lon_lat_df=pd.DataFrame(list(establishments.find(query).sort(sort)))

print(f'number of rows: {lon_lat_df.shape[0]}')
      
lon_lat_df.head(10)
# Out:
# number of rows: 87
#                         _id   FHRSID  ChangesByServerID  \
# 0  63cd56a93488378034972a44   695223                  0
# 1  63cd56a93488378034972a54  1380578                  0
# 2  63cd56a93488378034972a71   694609                  0
# 3  63cd56a93488378034972a87   695241                  0
# 4  63cd56a93488378034972a8a   694478                  0
# 5  63cd56a93488378034972a91   909912                  0
# 6  63cd56a93488378034972aac   694482                  0
# 7  63cd56a93488378034972aad   695204                  0
# 8  63cd56a93488378034972ad4   940026                  0
# 9  63cd56a93488378034972ad5  1211907                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000178842                              Iceland
# 1                    14425  Howe and Co Fish and Chips - Van 17
# 2             PI/000116619                            Volunteer
# 3             PI/000179088              Plumstead Manor Nursery
# 4             PI/000086506                    Atlantic Fish Bar
# 5             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 6             PI/000086551                               Greggs
# 7             PI/000177985                                Tesco
# 8             PI/000177403                           Abbi Wines
# 9                    13217                Dosa & Sambal Express
#
#                             BusinessType  BusinessTypeID  \
# 0  Retailers - supermarkets/hypermarkets            7840
# 1                         Mobile caterer            7846
# 2                      Pub/bar/nightclub            7843
# 3                        Caring Premises               5
# 4                 Takeaway/sandwich shop            7844
# 5                      Retailers - other            4613
# 6                 Takeaway/sandwich shop            7844
# 7  Retailers - supermarkets/hypermarkets            7840
# 8                      Retailers - other            4613
# 9                Restaurant/Cafe/Canteen               1
#
#                                         AddressLine1 AddressLine2  \
# 0                    144 - 146 Plumstead High Street
# 1  Restaurant And Premises 107A Plumstead High St...
# 2                    130 - 132 Plumstead High Street
# 3               Plumstead Manor School Old Mill Road
# 4                                   35 Lakedale Road
# 5                                   17 Lakedale Road
# 6                                    6 Lakedale Road
# 7                                   18 Lakedale Road
# 8                              12 - 14 Lakedale Road
# 9                         107A Plumstead High Street
#
#   AddressLine3 AddressLine4  PostCode Phone RatingValue     RatingKey  \
# 0       London    Greenwich  SE18 1JQ                 5  fhrs_5_en-gb
# 1       London    Greenwich  SE18 1SE                 5  fhrs_5_en-gb
# 2       London    Greenwich  SE18 1JQ                 5  fhrs_5_en-gb
# 3       London    Greenwich  SE18 1QG                 5  fhrs_5_en-gb
# 4       London    Greenwich  SE18 1PR                 5  fhrs_5_en-gb
# 5       London    Greenwich  SE18 1PP                 5  fhrs_5_en-gb
# 6       London    Greenwich  SE18 1PP                 5  fhrs_5_en-gb
# 7       London    Greenwich  SE18 1PP                 5  fhrs_5_en-gb
# 8       London    Greenwich  SE18 1PP                 5  fhrs_5_en-gb
# 9       London    Greenwich                           5  fhrs_5_en-gb
#
#             RatingDate LocalAuthorityCode LocalAuthorityName  \
# 0  2019-11-13T00:00:00                511          Greenwich
# 1  2021-11-11T00:00:00                511          Greenwich
# 2  2019-08-05T00:00:00                511          Greenwich
# 3  2021-06-16T00:00:00                511          Greenwich
# 4  2021-06-16T00:00:00                511          Greenwich
# 5  2020-10-20T00:00:00                511          Greenwich
# 6  2021-06-23T00:00:00                511          Greenwich
# 7  2020-10-20T00:00:00                511          Greenwich
# 8  2021-08-23T00:00:00                511          Greenwich
# 9  2020-07-09T00:00:00                511          Greenwich
#
#               LocalAuthorityWebSite    LocalAuthorityEmailAddress  \
# 0  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 1  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 2  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 3  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 4  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 5  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 6  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 7  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 8  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 9  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.0924199968576431, 'latitude': ...
# 1  {'longitude': 0.0925370007753372, 'latitude': ...
# 2     {'longitude': 0.09208, 'latitude': 51.4873437}
# 3  {'longitude': 0.0859939977526665, 'latitude': ...
# 4   {'longitude': 0.0912164, 'latitude': 51.4867296}
# 5   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 6  {'longitude': 0.0912820026278496, 'latitude': ...
# 7  {'longitude': 0.0912820026278496, 'latitude': ...
# 8   {'longitude': 0.0908895, 'latitude': 51.4871401}
# 9    {'longitude': 0.091566, 'latitude': 51.4877576}
#
#       Distance  NewRatingPending  \
# 0  4646.946071             False
# 1  4646.955931             False
# 2  4646.965635             False
# 3  4646.974010             False
# 4  4646.974612             False
# 5  4646.975587             False
# 6  4646.987290             False
# 7  4646.987290             False
# 8  4647.001583             False
# 9  4646.999554             False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links longitude latitude
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...      None     None

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query= {'$match': {'scores.Hygiene':0}}
# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}
# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1 }}
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
len(results)

# Print the first 10 results
for i in range(10):
    pprint(results[i])
# Out:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
grouped_df=pd.DataFrame(results)

# Display the number of rows in the DataFrame
print(f'number of rows: {grouped_df.shape[0]}')

# Display the first 10 rows of the DataFrame
grouped_df.head(10)
# Out:
# number of rows: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
